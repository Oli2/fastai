# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import torch

# %%
import fastai

# %%
import torchvision

# %%
import fastai.vision

# %%
path = '/Users/tomcheckiewics/Dropbox/PythonWorkingDirectory/Deep_Learning_A_Z/Volume 1 - Supervised Deep Learning/Part 2 - Convolutional Neural Networks (CNN)/Section 8 - Building a CNN/Convolutional_Neural_Networks/dataset/'

# %%
path
# Out:
# '/Users/tomcheckiewics/Dropbox/PythonWorkingDirectory/Deep_Learning_A_Z/Volume 1 - Supervised Deep Learning/Part 2 - Convolutional Neural Networks (CNN)/Section 8 - Building a CNN/Convolutional_Neural_Networks/dataset/'

# %%
from fastai.vision import *

# %%
doc(ImageDataBunch)

# %%
data = ImageDataBunch.from_folder(path, ds_tfms=get_transforms(), size=254)

# %% [markdown]
# setting the batch size to 16  (64 if on GPUs)

# %%
bs = 16

# %%
data.show_batch(rows=5, figsize=(7,6))

# %%
print(data.classes)
# Out:
# ['cats', 'dogs']

# %%
len(data.classes),data.c
# Out:
# (2, 2)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
